# %%
import random
import json
import pickle
import numpy as np

import nltk
from nltk.stem import WordNetLemmatizer

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD

# %%
lemmatizer = WordNetLemmatizer()

intents = json.loads(open('intents.json').read())

words, classes, documents = [], [] ,[]
ignore_letters = ['?', '!', ',', '.']

for intent in intents['intents']:
	for pattern in intent['patterns']:
		word_list = nltk.word_tokenize(pattern)
		words.extend(word_list)
		documents.append((word_list, intent['tag']))
		if intent['tag'] not in classes:
			classes.append(intent['tag'])

words = [lemmatizer.lemmatize(word) for word in words if word not in ignore_letters]
words = sorted(set(words))

classes = sorted(set(classes))

print(words)

pickle.dump(words, open('words.pkl', 'wb'))
pickle.dump(classes, open('classes.pkl', 'wb'))

training = []
output_empty = [0] * len(classes)

for document in documents:
	bag = []
	word_patterns = document[0]
	word_patterns = [lemmatizer.lemmatize(word.lower()) for word in word_patterns]
	for word in words:
		bag.append(1) if word in word_patterns else bag.append(0)

	output_row = list(output_empty)
	output_row[classes.index(document[1])] = 1
	training.append([bag, output_row])

random.shuffle(training)
training = np.array(training)

train_x = list(training[:, 0])
train_y = list(training[:, 1])

model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)

model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

hist = model.fit(np.array(train_x), np.array(train_y), epochs= 200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)
print('Done')
# Out:
# ["'s", 'Gday', 'a', 'able', 'afternoon', 'am', 'anyone', 'are', 'ask', 'assistance', 'best', 'bot', 'can', 'could', 'day', 'do', 'evening', 'going', 'good', 'hand', 'happening', 'have', 'hello', 'help', 'hey', 'hi', 'how', 'howdy', 'i', 'is', 'it', 'know', 'lend', 'morning', 'need', 'new', 'question', 'sup', 'the', 'there', 'thing', 'this', 'to', 'uncertain', 'up', 'use', 'wa', 'what', 'whats', 'who', 'wondering', 'yo', 'you']
# Epoch 1/200
# C:\Users\pluss\AppData\Local\Temp/ipykernel_14068/3033025581.py:41: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   training = np.array(training)
# 9/9 [==============================] - 0s 2ms/step - loss: 1.4007 - accuracy: 0.2558
# Epoch 2/200
# 9/9 [==============================] - 0s 2ms/step - loss: 1.3092 - accuracy: 0.4419
# Epoch 3/200
# 9/9 [==============================] - 0s 2ms/step - loss: 1.1608 - accuracy: 0.4884
# Epoch 4/200
# 9/9 [==============================] - 0s 2ms/step - loss: 1.0797 - accuracy: 0.6512
# Epoch 5/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.9425 - accuracy: 0.7209
# Epoch 6/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.8588 - accuracy: 0.7442
# Epoch 7/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.6986 - accuracy: 0.7674
# Epoch 8/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.5902 - accuracy: 0.8140
# Epoch 9/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.6537 - accuracy: 0.7907
# Epoch 10/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6895 - accuracy: 0.7442
# Epoch 11/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4301 - accuracy: 0.8605
# Epoch 12/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4682 - accuracy: 0.7907
# Epoch 13/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4236 - accuracy: 0.8140
# Epoch 14/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4010 - accuracy: 0.8605
# Epoch 15/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2901 - accuracy: 0.9767
# Epoch 16/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.2531 - accuracy: 0.9302
# Epoch 17/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3252 - accuracy: 0.8605
# Epoch 18/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.1973 - accuracy: 0.9535
# Epoch 19/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.1624 - accuracy: 0.9535
# Epoch 20/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1751 - accuracy: 0.9535
# Epoch 21/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1843 - accuracy: 0.9302
# Epoch 22/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.1716 - accuracy: 0.9535
# Epoch 23/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1447 - accuracy: 0.9535
# Epoch 24/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1302 - accuracy: 1.0000
# Epoch 25/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.1505 - accuracy: 0.9767
# Epoch 26/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0955 - accuracy: 0.9767
# Epoch 27/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0691 - accuracy: 1.0000
# Epoch 28/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0855 - accuracy: 0.9767
# Epoch 29/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1535 - accuracy: 0.9535
# Epoch 30/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0601 - accuracy: 1.0000
# Epoch 31/200
# 9/9 [==============================] - ETA: 0s - loss: 0.1313 - accuracy: 1.00 - 0s 1ms/step - loss: 0.1335 - accuracy: 0.9767
# Epoch 32/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1199 - accuracy: 0.9535
# Epoch 33/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1127 - accuracy: 0.9767
# Epoch 34/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0816 - accuracy: 1.0000
# Epoch 35/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1214 - accuracy: 0.9767
# Epoch 36/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0613 - accuracy: 1.0000
# Epoch 37/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0375 - accuracy: 0.9767
# Epoch 38/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0805 - accuracy: 0.9767
# Epoch 39/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0669 - accuracy: 1.0000
# Epoch 40/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0476 - accuracy: 1.0000
# Epoch 41/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0725 - accuracy: 0.9767
# Epoch 42/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0552 - accuracy: 0.9767
# Epoch 43/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0449 - accuracy: 0.9767
# Epoch 44/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0273 - accuracy: 1.0000
# Epoch 45/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0501 - accuracy: 1.0000
# Epoch 46/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0492 - accuracy: 1.0000
# Epoch 47/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1058 - accuracy: 0.9767
# Epoch 48/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0227 - accuracy: 1.0000
# Epoch 49/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0683 - accuracy: 0.9767
# Epoch 50/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0436 - accuracy: 1.0000
# Epoch 51/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0152 - accuracy: 1.0000
# Epoch 52/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0400 - accuracy: 0.9767
# Epoch 53/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0412 - accuracy: 1.0000
# Epoch 54/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0594 - accuracy: 0.9767
# Epoch 55/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0556 - accuracy: 0.9767
# Epoch 56/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0187 - accuracy: 1.0000
# Epoch 57/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 58/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 59/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0149 - accuracy: 1.0000
# Epoch 60/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0175 - accuracy: 1.0000
# Epoch 61/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0174 - accuracy: 1.0000
# Epoch 62/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0253 - accuracy: 1.0000
# Epoch 63/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0598 - accuracy: 0.9535
# Epoch 64/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0188 - accuracy: 1.0000
# Epoch 65/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0153 - accuracy: 1.0000
# Epoch 66/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 67/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0265 - accuracy: 1.0000
# Epoch 68/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0208 - accuracy: 1.0000
# Epoch 69/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0255 - accuracy: 1.0000
# Epoch 70/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0228 - accuracy: 1.0000
# Epoch 71/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0257 - accuracy: 1.0000
# Epoch 72/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0560 - accuracy: 0.9767
# Epoch 73/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0191 - accuracy: 1.0000
# Epoch 74/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 75/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0396 - accuracy: 0.9767
# Epoch 76/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0164 - accuracy: 1.0000
# Epoch 77/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 78/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0129 - accuracy: 1.0000
# Epoch 79/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0168 - accuracy: 1.0000
# Epoch 80/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0764 - accuracy: 0.9767
# Epoch 81/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0193 - accuracy: 1.0000
# Epoch 82/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0359 - accuracy: 0.9767
# Epoch 83/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0486 - accuracy: 1.0000
# Epoch 84/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 85/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0197 - accuracy: 1.0000
# Epoch 86/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0303 - accuracy: 1.0000
# Epoch 87/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 88/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0307 - accuracy: 0.9767
# Epoch 89/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0279 - accuracy: 1.0000
# Epoch 90/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0391 - accuracy: 0.9767
# Epoch 91/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 92/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0143 - accuracy: 1.0000
# Epoch 93/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 94/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0346 - accuracy: 1.0000
# Epoch 95/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0178 - accuracy: 1.0000
# Epoch 96/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 97/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 98/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 99/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 100/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0188 - accuracy: 1.0000
# Epoch 101/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 102/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 103/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 104/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 105/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 106/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0227 - accuracy: 1.0000
# Epoch 107/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 108/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0178 - accuracy: 1.0000
# Epoch 109/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 1.0000
# Epoch 110/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 111/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 112/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 113/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0294 - accuracy: 0.9767
# Epoch 114/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0714 - accuracy: 0.9767
# Epoch 115/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 116/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0247 - accuracy: 1.0000
# Epoch 117/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 118/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0127 - accuracy: 1.0000
# Epoch 119/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0153 - accuracy: 1.0000
# Epoch 120/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 121/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 122/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 123/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0284 - accuracy: 1.0000
# Epoch 124/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 125/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 126/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 127/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 128/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 129/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 1.0000
# Epoch 130/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 131/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 132/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 133/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 134/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 135/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 136/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 137/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 138/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 139/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0127 - accuracy: 1.0000
# Epoch 140/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 141/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 142/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 143/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 144/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0163 - accuracy: 1.0000
# Epoch 145/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0278 - accuracy: 0.9767
# Epoch 146/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 147/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 148/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 149/200
# 9/9 [==============================] - 0s 2ms/step - loss: 8.4157e-04 - accuracy: 1.0000
# Epoch 150/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 151/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 152/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 153/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 154/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 155/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0424 - accuracy: 0.9767
# Epoch 156/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 157/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.1252 - accuracy: 0.9767
# Epoch 158/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 159/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0105 - accuracy: 1.0000
# Epoch 160/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 161/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 162/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 163/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 164/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0143 - accuracy: 1.0000
# Epoch 165/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 166/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 167/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0209 - accuracy: 1.0000
# Epoch 168/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 169/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 170/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 171/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0125 - accuracy: 1.0000
# Epoch 172/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 173/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 174/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 175/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 176/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 177/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 178/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 179/200
# 9/9 [==============================] - 0s 2ms/step - loss: 5.3731e-04 - accuracy: 1.0000
# Epoch 180/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 181/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.1056 - accuracy: 0.9535
# Epoch 182/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 183/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 184/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 185/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0129 - accuracy: 1.0000
# Epoch 186/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0198 - accuracy: 1.0000
# Epoch 187/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 188/200
# 9/9 [==============================] - 0s 1ms/step - loss: 8.5472e-04 - accuracy: 1.0000
# Epoch 189/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 190/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 191/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 192/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0105 - accuracy: 1.0000
# Epoch 193/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 194/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 195/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 196/200
# 9/9 [==============================] - 0s 2ms/step - loss: 8.6867e-04 - accuracy: 1.0000
# Epoch 197/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 198/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 199/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 200/200
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0058 - accuracy: 1.0000
# Done

# %%
from nltk.stem import WordNetLemmatizer

from tensorflow.keras.models import load_model

# %%
##loading in data from model

lemmatizer = WordNetLemmatizer()
intents = json.loads(open('intents.json').read())

words = pickle.load(open('words.pkl', 'rb'))
classes = pickle.load(open('classes.pkl', 'rb'))
model = load_model('chatbot_model.h5')

##cleaning up sentences

def clean_up_sentence(sentence):
	sentence_words = nltk.word_tokenize(sentence)
	sentence_words = [lemmatizer.lemmatize(word) for word in sentence_words]
	return sentence_words

##getting bag of words

def bag_of_words(sentence):
	sentence_words = clean_up_sentence(sentence)
	bag = [0] * len(words)
	for w in sentence_words:
		for i, word in enumerate(words):
			if word == w:
				bag[i] = 1
	return np.array(bag)

##predicting class

def predict_class(sentence):
	bow = bag_of_words(sentence)
	res = model.predict(np.array([bow]))[0]
	error_threshold = .25
	results = [[i, r] for i, r in enumerate(res) if r > error_threshold]

	results.sort(key=lambda x: x[1], reverse=True)
	return_list = []
	for r in results:
		return_list.append({'intent': classes[r[0]], 'probability': str(r[1])})
	return return_list

##getting responce

def get_response(intents_list, intents_json):
	tag = intents_list[0]['intent']
	list_of_intents = intents_json['intents']
	for i in list_of_intents:
		if i['tag'] == tag:
			result = random.choice(i['responses'])
			break
	return result

print('Starting')

while True:
	message = input('')
	ints = predict_class(message)
	res = get_response(ints, intents)
	print(res)
# Out:
# Starting
#  hi
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14068/339938961.py in <module>
#      56         message = input('')
#      57         ints = predict_class(message)
# ---> 58         res = get_response(ints, intents)
#      59         print(res)
#
# ~\AppData\Local\Temp/ipykernel_14068/339938961.py in get_response(intents_list, intents_json)
#      47         for i in list_of_intents:
#      48                 if i['tag'] == tag:
# ---> 49                         result = random.choice(i['response'])
#      50                         break
#      51         return result
#
# KeyError: 'response'
