# %%
import random
import json
import pickle
import numpy as np

import nltk
from nltk.stem import WordNetLemmatizer

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD

# %%
lemmatizer = WordNetLemmatizer()

intents = json.loads(open('intents.json').read())

words, classes, documents = [], [] ,[]
ignore_letters = ['?', '!', ',', '.']

for intent in intents['intents']:
	for pattern in intent['patterns']:
		word_list = nltk.word_tokenize(pattern)
		words.extend(word_list)
		documents.append((word_list, intent['tag']))
		if intent['tag'] not in classes:
			classes.append(intent['tag'])

words = [lemmatizer.lemmatize(word) for word in words if word not in ignore_letters]
words = sorted(set(words))

classes = sorted(set(classes))

print(words)

pickle.dump(words, open('words.pkl', 'wb'))
pickle.dump(classes, open('classes.pkl', 'wb'))

training = []
output_empty = [0] * len(classes)

for document in documents:
	bag = []
	word_patterns = document[0]
	word_patterns = [lemmatizer.lemmatize(word.lower()) for word in word_patterns]
	for word in words:
		bag.append(1) if word in word_patterns else bag.append(0)

	output_row = list(output_empty)
	output_row[classes.index(document[1])] = 1
	training.append([bag, output_row])

random.shuffle(training)
training = np.array(training)

train_x = list(training[:, 0])
train_y = list(training[:, 1])

model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)

model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

hist = model.fit(np.array(train_x), np.array(train_y), epochs= 200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)
print('Done')
# Out:
# ["'d", "'m", "'re", "'s", "'ve", '(', ')', 'ASD', 'Can', 'Done', 'Excellent', 'Gday', 'How', 'I', 'If', 'Is', 'It', 'Many', 'N', 'No', 'Please', 'Rob', 'Thank', 'Thanks', 'That', 'What', 'When', 'Y', 'Your', 'a', 'able', 'about', 'accept', 'add', 'afternoon', 'again', 'am', 'answer', 'any', 'anyone', 'appreciate', 'appreciated', 'appreciation', 'are', 'ask', 'assistance', 'autims', 'autism', 'be', 'best', 'bot', 'bunch', 'bye', 'ca', 'can', 'care', 'catch', 'cause', 'chatbot', 'child', 'complain', 'complaint', 'could', 'day', 'deepest', 'describe', 'diagnos', 'diagnosed', 'diagnosis', 'did', 'different', 'differently', 'dislike', 'do', 'doctor', 'doe', 'done', 'dumb', 'easy', 'enough', 'environmental', 'evening', 'ever', 'express', 'feedback', 'first', 'for', 'forward', 'function', 'genetic', 'get', 'give', 'go', 'going', 'good', 'goodbye', 'goodnight', 'got', 'grateful', 'greatly', 'ha', 'hand', 'handle', 'happening', 'have', 'head', 'hear', 'hello', 'help', 'helped', 'here', 'hey', 'hi', 'hit', 'hoping', 'how', 'howdy', 'i', 'if', 'in', 'incorrect', 'indicator', 'information', 'inhereited', 'inherited', 'integrate', 'interest', 'interested', 'into', 'is', 'it', 'kind', 'know', 'later', 'learn', 'learning', 'leave', 'lend', 'like', 'likely', 'lol', 'look', 'looking', 'lot', 'machine', 'made', 'make', 'me', 'mean', 'meeting', 'message', 'might', 'morning', 'much', 'must', 'my', 'n', "n't", 'need', 'needed', 'new', 'next', 'nice', 'night', 'no', 'nope', 'not', 'of', 'off', 'on', 'one', 'or', 'our', 'out', 'owe', 'peace', 'please', 'policy', 'privacy', 'private', 'public', 'purpose', 'question', 'really', 'record', 'recorded', 'rephrase', 'response', 'right', 'risk', 'road', 'rob', 'rock', 'say', 'saying', 'see', 'seeing', 'should', 'so', 'some', 'someone', 'something', 'soon', 'stupid', 'sup', 'support', 'symptom', 'ta', 'take', 'talk', 'tell', 'test', 'thank', 'thankful', 'thanks', 'that', 'the', 'their', 'them', 'there', 'thing', 'think', 'this', 'through', 'time', 'to', 'ton', 'train', 'training', 'treat', 'treatment', 'truly', 'uncertain', 'understand', 'until', 'up', 'use', 'using', 'value', 'very', 'wa', 'walk', 'want', 'wanted', 'way', 'what', 'whats', 'when', 'who', 'will', 'with', 'wondering', 'word', 'work', 'worried', 'wrong', 'y', 'yo', 'you', 'your']
# Epoch 1/200
# C:\Users\pluss\AppData\Local\Temp/ipykernel_6564/3033025581.py:41: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   training = np.array(training)
# 46/46 [==============================] - 0s 2ms/step - loss: 2.9521 - accuracy: 0.1223
# Epoch 2/200
# 46/46 [==============================] - 0s 2ms/step - loss: 2.7208 - accuracy: 0.1878
# Epoch 3/200
# 46/46 [==============================] - 0s 1ms/step - loss: 2.5422 - accuracy: 0.2664
# Epoch 4/200
# 46/46 [==============================] - 0s 2ms/step - loss: 2.3606 - accuracy: 0.2838
# Epoch 5/200
# 46/46 [==============================] - 0s 2ms/step - loss: 2.1459 - accuracy: 0.2882
# Epoch 6/200
# 46/46 [==============================] - 0s 2ms/step - loss: 1.9588 - accuracy: 0.3799
# Epoch 7/200
# 46/46 [==============================] - 0s 2ms/step - loss: 1.7634 - accuracy: 0.4498
# Epoch 8/200
# 46/46 [==============================] - 0s 2ms/step - loss: 1.5830 - accuracy: 0.5066
# Epoch 9/200
# 46/46 [==============================] - 0s 1ms/step - loss: 1.4546 - accuracy: 0.5502
# Epoch 10/200
# 46/46 [==============================] - 0s 1ms/step - loss: 1.3472 - accuracy: 0.6245
# Epoch 11/200
# 46/46 [==============================] - 0s 2ms/step - loss: 1.2784 - accuracy: 0.6157
# Epoch 12/200
# 46/46 [==============================] - 0s 2ms/step - loss: 1.1631 - accuracy: 0.6419
# Epoch 13/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.9918 - accuracy: 0.6987
# Epoch 14/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.9296 - accuracy: 0.7205
# Epoch 15/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.8468 - accuracy: 0.7380
# Epoch 16/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.8104 - accuracy: 0.7773
# Epoch 17/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6587 - accuracy: 0.8122
# Epoch 18/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6727 - accuracy: 0.7773
# Epoch 19/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.7483 - accuracy: 0.7773
# Epoch 20/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6109 - accuracy: 0.7948
# Epoch 21/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.5468 - accuracy: 0.8428
# Epoch 22/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4962 - accuracy: 0.8428
# Epoch 23/200
# 46/46 [==============================] - ETA: 0s - loss: 0.5452 - accuracy: 0.83 - 0s 2ms/step - loss: 0.5176 - accuracy: 0.8428
# Epoch 24/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.4652 - accuracy: 0.8603
# Epoch 25/200
# 46/46 [==============================] - ETA: 0s - loss: 0.4246 - accuracy: 0.88 - 0s 2ms/step - loss: 0.4701 - accuracy: 0.8559
# Epoch 26/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4371 - accuracy: 0.8603
# Epoch 27/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.3924 - accuracy: 0.8646
# Epoch 28/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.3538 - accuracy: 0.8603
# Epoch 29/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.3993 - accuracy: 0.8908
# Epoch 30/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3907 - accuracy: 0.8646
# Epoch 31/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.3548 - accuracy: 0.8908
# Epoch 32/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3525 - accuracy: 0.8865
# Epoch 33/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2581 - accuracy: 0.9301
# Epoch 34/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3480 - accuracy: 0.8952
# Epoch 35/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.3415 - accuracy: 0.8908
# Epoch 36/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.3920 - accuracy: 0.8865
# Epoch 37/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3554 - accuracy: 0.8996
# Epoch 38/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3859 - accuracy: 0.8777
# Epoch 39/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.1955 - accuracy: 0.9432
# Epoch 40/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.3009 - accuracy: 0.9083
# Epoch 41/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2711 - accuracy: 0.9170
# Epoch 42/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2025 - accuracy: 0.9563
# Epoch 43/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1995 - accuracy: 0.9301
# Epoch 44/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2113 - accuracy: 0.9170
# Epoch 45/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2050 - accuracy: 0.9345
# Epoch 46/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2209 - accuracy: 0.9389
# Epoch 47/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2059 - accuracy: 0.9476
# Epoch 48/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.1872 - accuracy: 0.9607
# Epoch 49/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2101 - accuracy: 0.9301
# Epoch 50/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1606 - accuracy: 0.9389
# Epoch 51/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2282 - accuracy: 0.9476
# Epoch 52/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2294 - accuracy: 0.9214
# Epoch 53/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1919 - accuracy: 0.9476
# Epoch 54/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.1159 - accuracy: 0.9694
# Epoch 55/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.1605 - accuracy: 0.9520
# Epoch 56/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1387 - accuracy: 0.9651
# Epoch 57/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1498 - accuracy: 0.9520
# Epoch 58/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1537 - accuracy: 0.9476
# Epoch 59/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1654 - accuracy: 0.9432
# Epoch 60/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2402 - accuracy: 0.9258
# Epoch 61/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1445 - accuracy: 0.9563
# Epoch 62/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.1787 - accuracy: 0.9345
# Epoch 63/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1657 - accuracy: 0.9345
# Epoch 64/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1985 - accuracy: 0.9389
# Epoch 65/200
# 46/46 [==============================] - 0s 3ms/step - loss: 0.1048 - accuracy: 0.9651
# Epoch 66/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1527 - accuracy: 0.9651
# Epoch 67/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.1347 - accuracy: 0.9520
# Epoch 68/200
# 46/46 [==============================] - 0s 953us/step - loss: 0.1141 - accuracy: 0.9651
# Epoch 69/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.1392 - accuracy: 0.9563
# Epoch 70/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.1336 - accuracy: 0.9651
# Epoch 71/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.1286 - accuracy: 0.9563
# Epoch 72/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.1295 - accuracy: 0.9563
# Epoch 73/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1214 - accuracy: 0.9520
# Epoch 74/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1115 - accuracy: 0.9738
# Epoch 75/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1645 - accuracy: 0.9563
# Epoch 76/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1321 - accuracy: 0.9651
# Epoch 77/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1526 - accuracy: 0.9345
# Epoch 78/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0923 - accuracy: 0.9738
# Epoch 79/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1347 - accuracy: 0.9563
# Epoch 80/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1272 - accuracy: 0.9563
# Epoch 81/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1114 - accuracy: 0.9738
# Epoch 82/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1710 - accuracy: 0.9345
# Epoch 83/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1777 - accuracy: 0.9476
# Epoch 84/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1106 - accuracy: 0.9694
# Epoch 85/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0618 - accuracy: 0.9913
# Epoch 86/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.1771 - accuracy: 0.9432
# Epoch 87/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0811 - accuracy: 0.9825
# Epoch 88/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0650 - accuracy: 0.9782
# Epoch 89/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0837 - accuracy: 0.9825
# Epoch 90/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1118 - accuracy: 0.9651
# Epoch 91/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1069 - accuracy: 0.9520
# Epoch 92/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0790 - accuracy: 0.9738
# Epoch 93/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0995 - accuracy: 0.9651
# Epoch 94/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0686 - accuracy: 0.9738
# Epoch 95/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0940 - accuracy: 0.9607
# Epoch 96/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0959 - accuracy: 0.9738
# Epoch 97/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0934 - accuracy: 0.9520
# Epoch 98/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1221 - accuracy: 0.9651
# Epoch 99/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1119 - accuracy: 0.9694
# Epoch 100/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0477 - accuracy: 0.9913
# Epoch 101/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0956 - accuracy: 0.9738
# Epoch 102/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0745 - accuracy: 0.9782
# Epoch 103/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0978 - accuracy: 0.9738
# Epoch 104/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0881 - accuracy: 0.9825
# Epoch 105/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0757 - accuracy: 0.9782
# Epoch 106/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1117 - accuracy: 0.9563
# Epoch 107/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1015 - accuracy: 0.9607
# Epoch 108/200
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0879 - accuracy: 0.9825: 0s - loss: 0.1188 - accuracy:
# Epoch 109/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0705 - accuracy: 0.9825
# Epoch 110/200
# 46/46 [==============================] - 0s 3ms/step - loss: 0.1208 - accuracy: 0.9651
# Epoch 111/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1103 - accuracy: 0.9607
# Epoch 112/200
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0849 - accuracy: 0.9738
# Epoch 113/200
# 46/46 [==============================] - 0s 3ms/step - loss: 0.1296 - accuracy: 0.9520
# Epoch 114/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0881 - accuracy: 0.9869
# Epoch 115/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0770 - accuracy: 0.9738
# Epoch 116/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0766 - accuracy: 0.9738
# Epoch 117/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0374 - accuracy: 0.9956
# Epoch 118/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0640 - accuracy: 0.9782
# Epoch 119/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0551 - accuracy: 0.9869
# Epoch 120/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0664 - accuracy: 0.9825
# Epoch 121/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1097 - accuracy: 0.9607
# Epoch 122/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0658 - accuracy: 0.9825
# Epoch 123/200
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0895 - accuracy: 0.9694
# Epoch 124/200
# 46/46 [==============================] - 0s 4ms/step - loss: 0.1119 - accuracy: 0.9607
# Epoch 125/200
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0638 - accuracy: 0.9782
# Epoch 126/200
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0733 - accuracy: 0.9738
# Epoch 127/200
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0536 - accuracy: 0.9825
# Epoch 128/200
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0954 - accuracy: 0.9782
# Epoch 129/200
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0605 - accuracy: 0.9913
# Epoch 130/200
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0246 - accuracy: 1.0000
# Epoch 131/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1294 - accuracy: 0.9651
# Epoch 132/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0743 - accuracy: 0.9738
# Epoch 133/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.1018 - accuracy: 0.9694
# Epoch 134/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0941 - accuracy: 0.9651
# Epoch 135/200
# 46/46 [==============================] - 0s 864us/step - loss: 0.1030 - accuracy: 0.9825
# Epoch 136/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0512 - accuracy: 0.9782
# Epoch 137/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0730 - accuracy: 0.9738
# Epoch 138/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0813 - accuracy: 0.9651
# Epoch 139/200
# 46/46 [==============================] - 0s 975us/step - loss: 0.0881 - accuracy: 0.9651
# Epoch 140/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0737 - accuracy: 0.9782
# Epoch 141/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0556 - accuracy: 0.9825
# Epoch 142/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0515 - accuracy: 0.9869
# Epoch 143/200
# 46/46 [==============================] - 0s 975us/step - loss: 0.1050 - accuracy: 0.9694
# Epoch 144/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.1082 - accuracy: 0.9694
# Epoch 145/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0731 - accuracy: 0.9782
# Epoch 146/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0686 - accuracy: 0.9869
# Epoch 147/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0412 - accuracy: 0.9913
# Epoch 148/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0814 - accuracy: 0.9738
# Epoch 149/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0679 - accuracy: 0.9738
# Epoch 150/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0587 - accuracy: 0.9825
# Epoch 151/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0866 - accuracy: 0.9738
# Epoch 152/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0817 - accuracy: 0.9825
# Epoch 153/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0694 - accuracy: 0.9782
# Epoch 154/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0370 - accuracy: 0.9913
# Epoch 155/200
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0987 - accuracy: 0.9782
# Epoch 156/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0709 - accuracy: 0.9782
# Epoch 157/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0400 - accuracy: 0.9956
# Epoch 158/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0251 - accuracy: 1.0000
# Epoch 159/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0656 - accuracy: 0.9913
# Epoch 160/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0515 - accuracy: 0.9738
# Epoch 161/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0349 - accuracy: 0.9913
# Epoch 162/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0963 - accuracy: 0.9607
# Epoch 163/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0421 - accuracy: 0.9825
# Epoch 164/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0706 - accuracy: 0.9825
# Epoch 165/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0544 - accuracy: 0.9913
# Epoch 166/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0420 - accuracy: 0.9913
# Epoch 167/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0298 - accuracy: 0.9956
# Epoch 168/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0268 - accuracy: 0.9956
# Epoch 169/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0274 - accuracy: 0.9956
# Epoch 170/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0495 - accuracy: 0.9782
# Epoch 171/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0555 - accuracy: 0.9825
# Epoch 172/200
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0390 - accuracy: 0.9825
# Epoch 173/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0355 - accuracy: 0.9869
# Epoch 174/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0355 - accuracy: 0.9913
# Epoch 175/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0802 - accuracy: 0.9738
# Epoch 176/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0665 - accuracy: 0.9782
# Epoch 177/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0743 - accuracy: 0.9738
# Epoch 178/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0380 - accuracy: 0.9913
# Epoch 179/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0353 - accuracy: 0.9825
# Epoch 180/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0306 - accuracy: 0.9913
# Epoch 181/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0734 - accuracy: 0.9651
# Epoch 182/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0605 - accuracy: 0.9825
# Epoch 183/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0425 - accuracy: 0.9825
# Epoch 184/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0629 - accuracy: 0.9913
# Epoch 185/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0705 - accuracy: 0.9782
# Epoch 186/200
# 46/46 [==============================] - 0s 931us/step - loss: 0.0521 - accuracy: 0.9782
# Epoch 187/200
# 46/46 [==============================] - 0s 931us/step - loss: 0.0448 - accuracy: 0.9869
# Epoch 188/200
# 46/46 [==============================] - 0s 953us/step - loss: 0.0648 - accuracy: 0.9782
# Epoch 189/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0392 - accuracy: 0.9869
# Epoch 190/200
# 46/46 [==============================] - 0s 931us/step - loss: 0.0281 - accuracy: 0.9869
# Epoch 191/200
# 46/46 [==============================] - 0s 931us/step - loss: 0.0490 - accuracy: 0.9869
# Epoch 192/200
# 46/46 [==============================] - 0s 997us/step - loss: 0.0839 - accuracy: 0.9738
# Epoch 193/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0486 - accuracy: 0.9782
# Epoch 194/200
# 46/46 [==============================] - 0s 931us/step - loss: 0.0343 - accuracy: 0.9913
# Epoch 195/200
# 46/46 [==============================] - 0s 953us/step - loss: 0.0333 - accuracy: 0.9913
# Epoch 196/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0648 - accuracy: 0.9738
# Epoch 197/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0577 - accuracy: 0.9825
# Epoch 198/200
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0556 - accuracy: 0.9738
# Epoch 199/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0485 - accuracy: 0.9869
# Epoch 200/200
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0511 - accuracy: 0.9869
# Done

# %%
import os

from nltk.stem import WordNetLemmatizer

from tensorflow.keras.models import load_model

from autocorrect import Speller

# %%
##loading in data from model

lemmatizer = WordNetLemmatizer()
intents = json.loads(open('intents.json').read())

words = pickle.load(open('words.pkl', 'rb'))
classes = pickle.load(open('classes.pkl', 'rb'))
model = load_model('chatbot_model.h5')

spell = Speller(lang='en')

##cleaning up sentences

def clean_up_sentence(sentence):
	sentence_words = nltk.word_tokenize(sentence)
	sentence_words = [lemmatizer.lemmatize(word) for word in sentence_words]
	return sentence_words

##getting bag of words

def bag_of_words(sentence):
	sentence_words = clean_up_sentence(sentence)
	bag = [0] * len(words)
	for w in sentence_words:
		for i, word in enumerate(words):
			if word == w:
				bag[i] = 1
	return np.array(bag)

##predicting class

def predict_class(sentence):
	bow = bag_of_words(sentence)
	res = model.predict(np.array([bow]))[0]
	error_threshold = .25
	results = [[i, r] for i, r in enumerate(res) if r > error_threshold]

	results.sort(key=lambda x: x[1], reverse=True)
	return_list = []
	for r in results:
		return_list.append({'intent': classes[r[0]], 'probability': str(r[1])})
	return return_list

##getting responce

def get_response(intents_list, intents_json):
	tag = intents_list[0]['intent']
	list_of_intents = intents_json['intents']
	for i in list_of_intents:
		if i['tag'] == tag:
			result = random.choice(i['responses'])
			break
	return result

# %%
## variable finder

def var_finder(lst, var_searching, return_var, fail_var):
    var_ = 0
    for i in lst:
        if i == var_searching:
            var_ = 1
            break
    if var_ == 1:
        return (return_var)
    else:
        return (fail_var)

## getting all responses
    
def get_all_responses(var_name):
    list_ = intents['intents']
    for i in list_:
        if i['tag'] == var_name:
            return((i['responses']))
        

print('Bot is on, say hi!')

res = 'temp'

while True:
	add_to_database = get_all_responses('add to databse now')
	message = spell(input('').lower())

	## test variable, remove after training is done
	if message == 'break':
		print('turning off')
		break

	elif res == var_finder(add_to_database, res, res, False):
		message_0 = input('').lower()
		list_temp = []
		list_temp.append(message)
		list_temp.append(message_0)
		res = get_response([{'intent': 'training done', 'probability': '1'}], intents)
		print(res)


	else:
		ints = predict_class(message)
        ## bot is certain enough its the correct response 
		if float(ints[0]['probability']) > .98:
			print(float(ints[0]['probability']))
			res = get_response(ints, intents)
        ## bot is uncertain answer is correct result
		else:
			print(float(ints[0]['probability']))
			print(message)
			res = get_response([{'intent': 'bot uncertain', 'probability': '1'}], intents)
		print(res)
# Out:
# Bot is on, say hi!
#  break
# turning off

# %%
def phrase_creator(list1, list2, list3):
	list_ = []
	for i in list1:
		for j in list2:
			for k in list3:
				list_.append(i+j+k)
	return(list_)

## Pattern: Greeting. Brief summary of fuctions. Segway into asking how it can help.
list1 = ["Glad it helped! ", "Happy it helped! ", "Great! ", "Your welcome! ", "Perfect! "]
list2 = ["Anything else?", "How else can I help?", "Do you need anything else?", "Is there something else I can do for you?", "Need anything else?"]
list3 = [""]

str(phrase_creator(list1, list2, list3)).replace("'", '"')
# Out:
# '["Glad it helped! Anything else?", "Glad it helped! How else can I help?", "Glad it helped! Do you need anything else?", "Glad it helped! Is there something else I can do for you?", "Glad it helped! Need anything else?", "Happy it helped! Anything else?", "Happy it helped! How else can I help?", "Happy it helped! Do you need anything else?", "Happy it helped! Is there something else I can do for you?", "Happy it helped! Need anything else?", "Great! Anything else?", "Great! How else can I help?", "Great! Do you need anything else?", "Great! Is there something else I can do for you?", "Great! Need anything else?", "Your welcome! Anything else?", "Your welcome! How else can I help?", "Your welcome! Do you need anything else?", "Your welcome! Is there something else I can do for you?", "Your welcome! Need anything else?", "Perfect! Anything else?", "Perfect! How else can I help?", "Perfect! Do you need anything else?", "Perfect! Is there something else I can do for you?", "Perfect! Need anything else?"]'

# %%
a = '"patterns": ["Can you tell me about asthma", "What is asthma", "what does it mean that my child has asthma", "what does it mean for someone to have asthma"],"patterns": ["what are the symptoms of autims", "what are the indicators of asthma", "how do I know if someone has autims", "how can I tell if someone has asthma", "what are indicators of asthma", "can you tell me the symptoms of asthma", "what should I look for to know if someone has asthma", "what should I look for to know if my child has asthma"],"patterns": ["How do you diagnos asthma", "are their tests for asthma", "When can ASD be diagnosed", "what is the diagnosis for asthma?"],"patterns": ["Is there a treatment for asthma", "how do you treat ASD", "what can be done for my child with asthma", "how can I help my child with asthma", "what is the best way to treat asthma", "can you tell me some ways to treat asthma?"],"patterns": ["what are some of the risks of asthma", "What are likely causes of asthma", "how did my child get asthma", "how does someone get asthma" , "is asthma inherited", "is asthma genetic"],"patterns": ["what do I do if I think my child might have asthma?", "Im worried my child might have asthma what do I do?", "If someone has asthma what should you do?"],'

a.replace('asthma', 'diabetes')
# Out:
# '"patterns": ["Can you tell me about diabetes", "What is diabetes", "what does it mean that my child has diabetes", "what does it mean for someone to have diabetes"],"patterns": ["what are the symptoms of autims", "what are the indicators of diabetes", "how do I know if someone has autims", "how can I tell if someone has diabetes", "what are indicators of diabetes", "can you tell me the symptoms of diabetes", "what should I look for to know if someone has diabetes", "what should I look for to know if my child has diabetes"],"patterns": ["How do you diagnos diabetes", "are their tests for diabetes", "When can ASD be diagnosed", "what is the diagnosis for diabetes?"],"patterns": ["Is there a treatment for diabetes", "how do you treat ASD", "what can be done for my child with diabetes", "how can I help my child with diabetes", "what is the best way to treat diabetes", "can you tell me some ways to treat diabetes?"],"patterns": ["what are some of the risks of diabetes", "What are likely causes of diabetes", "how did my child get diabetes", "how does someone get diabetes" , "is diabetes inherited", "is diabetes genetic"],"patterns": ["what do I do if I think my child might have diabetes?", "Im worried my child might have diabetes what do I do?", "If someone has diabetes what should you do?"],'

# %%
"patterns": ["Can you tell me about diabetes", "What is diabetes", "what does it mean that my child has diabetes", "what does it mean for someone to have diabetes"],
"patterns": ["what are the symptoms of autims", "what are the indicators of diabetes", "how do I know if someone has autims", "how can I tell if someone has diabetes", "what are indicators of diabetes", "can you tell me the symptoms of diabetes", "what should I look for to know if someone has diabetes", "what should I look for to know if my child has diabetes"],
"patterns": ["How do you diagnos diabetes", "are their tests for diabetes", "When can ASD be diagnosed", "what is the diagnosis for diabetes?"],
"patterns": ["Is there a treatment for diabetes", "how do you treat ASD", "what can be done for my child with diabetes", "how can I help my child with diabetes", "what is the best way to treat diabetes", "can you tell me some ways to treat diabetes?"],
"patterns": ["what are some of the risks of diabetes", "What are likely causes of diabetes", "how did my child get diabetes", "how does someone get diabetes" , "is diabetes inherited", "is diabetes genetic"],
"patterns": ["what do I do if I think my child might have diabetes?", "Im worried my child might have diabetes what do I do?", "If someone has diabetes what should you do?"],'

# %%
Take your medicine exactly as your doctor tells you and stay away from things that can trigger an attack to control your asthma. Everyone with asthma does not take the same medicine. You can breathe in some medicines and take other medicines as a pill. Asthma medicines come in two types—quick-relief and long-term control. Quick-relief medicines control the symptoms of an asthma attack. If you need to use your quick-relief medicines more and more, visit your doctor to see if you need a different medicine. Long-term control medicines help you have fewer and milder attacks, but they don’t help you while you are having an asthma attack.
